# %% [markdown]
# ### kajal Agunde

# %%
# import csv data file 
import pandas as pd 
df=pd.read_csv("fortune1000.csv")
df
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
# summary function of data

# %%
# first 5 obs 
df.head()
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
# transposing the data set 
df.head().T
# Out:
#                                0                   1  \
# Rank                           1                   2
# Company                  Walmart         Exxon Mobil
# Sector                 Retailing              Energy
# Industry   General Merchandisers  Petroleum Refining
# Location         Bentonville, AR          Irving, TX
# Revenue                   482130              246204
# Profits                    14694               16150
# Employees                2300000               75600
#
#                                      2  \
# Rank                                 3
# Company                          Apple
# Sector                      Technology
# Industry   Computers, Office Equipment
# Location                 Cupertino, CA
# Revenue                         233715
# Profits                          53394
# Employees                       110000
#
#                                                   3                         4
# ...

# %%
df.tail(25)
# Out:
#      Rank                        Company                        Sector  \
# 975   976            First Republic Bank                    Financials
# 976   977              Hill-Rom Holdings                   Health Care
# 977   978             Providence Service                   Health Care
# 978   979  Allison Transmission Holdings        Motor Vehicles & Parts
# 979   980                          Spire                        Energy
# 980   981                     WPX Energy                        Energy
# 981   982               Century Aluminum                     Materials
# 982   983       Adams Resources & Energy                        Energy
# 983   984          Nuance Communications                    Technology
# 984   985              Primoris Services    Engineering & Construction
# 985   986     Schnitzer Steel Industries                     Materials
# 986   987          Delta Tucker Holdings           Aerospace & Defense
# ...

# %%
## getting some information about data set by describe () or info()

# %%
df.describe()
# Out:
#              Rank        Revenue       Profits     Employees
# count  1000.00000    1000.000000   1000.000000  1.000000e+03
# mean    500.49600   13535.525000    894.093000  3.302800e+04
# std     288.81727   28820.519135   3297.063594  9.042769e+04
# min       1.00000    1895.000000 -23119.000000  5.200000e+01
# 25%     250.75000    2898.250000     82.750000  6.405250e+03
# 50%     500.50000    5113.000000    282.500000  1.251950e+04
# 75%     750.25000   11386.000000    784.500000  2.812500e+04
# max    1000.00000  482130.000000  53394.000000  2.300000e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rank       1000 non-null   int64
#  1   Company    1000 non-null   object
#  2   Sector     1000 non-null   object
#  3   Industry   1000 non-null   object
#  4   Location   1000 non-null   object
#  5   Revenue    1000 non-null   int64
#  6   Profits    1000 non-null   int64
#  7   Employees  1000 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 62.6+ KB

# %%
df.describe(include=['object'])
# Out:
#                       Company      Sector                    Industry  \
# count                    1000        1000                        1000
# unique                    996          21                          73
# top     Host Hotels & Resorts  Financials  Specialty Retailers: Other
# freq                        2         139                          42
#
#             Location
# count           1000
# unique           416
# top     New York, NY
# freq              72

# %%
df.nunique()
# Out:
# Rank         996
# Company      996
# Sector        21
# Industry      73
# Location     416
# Revenue      945
# Profits      760
# Employees    755
# dtype: int64

# %%
df.columns
# Out:
# Index(['Rank', 'Company', 'Sector', 'Industry', 'Location', 'Revenue',
#        'Profits', 'Employees'],
#       dtype='object')

# %%
# selecting a single column
df['Company']
# Out:
# 0                         Walmart
# 1                     Exxon Mobil
# 2                           Apple
# 3              Berkshire Hathaway
# 4                        McKesson
#                   ...
# 995    New York Community Bancorp
# 996     Portland General Electric
# 997     Portland General Electric
# 998                       Wendy’s
# 999             Briggs & Stratton
# Name: Company, Length: 1000, dtype: object

# %%
# for multiple column
df[['Sector','Industry','Company']]
# Out:
#                            Sector                                  Industry  \
# 0                       Retailing                     General Merchandisers
# 1                          Energy                        Petroleum Refining
# 2                      Technology               Computers, Office Equipment
# 3                      Financials  Insurance: Property and Casualty (Stock)
# 4                     Health Care                  Wholesalers: Health Care
# ..                            ...                                       ...
# 995                    Financials                          Commercial Banks
# 996                        Energy               Utilities: Gas and Electric
# 997                        Energy               Utilities: Gas and Electric
# 998  Hotels, Resturants & Leisure                             Food Services
# 999                   Industrials                      Industrial Machinery
#
#                         Company
# ...

# %%
# indexing loc and iloc

# %%
df.iloc[:5]
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
df.iloc[1:4,5:6]
# Out:
#    Revenue
# 1   246204
# 2   233715
# 3   210821

# %%
df.iloc[1:15,1:4]
# Out:
#                Company                  Sector  \
# 1          Exxon Mobil                  Energy
# 2                Apple              Technology
# 3   Berkshire Hathaway              Financials
# 4             McKesson             Health Care
# 5   UnitedHealth Group             Health Care
# 6           CVS Health    Food and Drug Stores
# 7       General Motors  Motor Vehicles & Parts
# 8           Ford Motor  Motor Vehicles & Parts
# 9                 AT&T      Telecommunications
# 10    General Electric             Industrials
# 11   AmerisourceBergen             Health Care
# 12             Verizon      Telecommunications
# 13             Chevron                  Energy
# 14              Costco               Retailing
#
#                                     Industry
# 1                         Petroleum Refining
# 2                Computers, Office Equipment
# 3   Insurance: Property and Casualty (Stock)
# 4                   Wholesalers: Health Care
# ...

# %%
df.iloc[:5,]
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
df.iloc[0:50,0:8:2]
# Out:
#     Rank                     Sector           Location  Profits
# 0      1                  Retailing    Bentonville, AR    14694
# 1      2                     Energy         Irving, TX    16150
# 2      3                 Technology      Cupertino, CA    53394
# 3      4                 Financials          Omaha, NE    24083
# 4      5                Health Care  San Francisco, CA     1476
# 5      6                Health Care     Minnetonka, MN     5813
# 6      7       Food and Drug Stores     Woonsocket, RI     5237
# 7      8     Motor Vehicles & Parts        Detroit, MI     9687
# 8      9     Motor Vehicles & Parts       Dearborn, MI     7373
# 9     10         Telecommunications         Dallas, TX    13345
# 10    11                Industrials      Fairfield, CT    -6126
# 11    12                Health Care   Chesterbrook, PA     -135
# 12    13         Telecommunications       New York, NY    17879
# 13    14                     Energy      San Ramon, CA     4587
# ...

# %%
df.iloc[0:8:2,0:8:2]
# Out:
#    Rank                Sector           Location  Profits
# 0     1             Retailing    Bentonville, AR    14694
# 2     3            Technology      Cupertino, CA    53394
# 4     5           Health Care  San Francisco, CA     1476
# 6     7  Food and Drug Stores     Woonsocket, RI     5237

# %%
df.iloc[0:20][['Profits','Sector','Company']]
# Out:
#     Profits                  Sector                   Company
# 0     14694               Retailing                   Walmart
# 1     16150                  Energy               Exxon Mobil
# 2     53394              Technology                     Apple
# 3     24083              Financials        Berkshire Hathaway
# 4      1476             Health Care                  McKesson
# 5      5813             Health Care        UnitedHealth Group
# 6      5237    Food and Drug Stores                CVS Health
# 7      9687  Motor Vehicles & Parts            General Motors
# 8      7373  Motor Vehicles & Parts                Ford Motor
# 9     13345      Telecommunications                      AT&T
# 10    -6126             Industrials          General Electric
# 11     -135             Health Care         AmerisourceBergen
# 12    17879      Telecommunications                   Verizon
# 13     4587                  Energy                   Chevron
# ...

# %%
df.iloc[45:,4:]
# Out:
#             Location  Revenue  Profits  Employees
# 45      Hartford, CT    60337     2390      50100
# 46   Mooresville, NC    59074     2546     225000
# 47       Atlanta, GA    58363     4844     341240
# 48      New York, NY    58327     2196      66400
# 49        Newark, NJ    57119     5642      49384
# ..               ...      ...      ...        ...
# 995     Westbury, NY     1902      -47       3448
# 996     Portland, OR     1898      172       2646
# 997     Portland, OR     1898      172       2646
# 998       Dublin, OH     1896      161      21200
# 999    Wauwatosa, WI     1895       46       5480
#
# [955 rows x 4 columns]

# %%
df.iloc[:5,:4]
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry
# 0                     General Merchandisers
# 1                        Petroleum Refining
# 2               Computers, Office Equipment
# 3  Insurance: Property and Casualty (Stock)
# 4                  Wholesalers: Health Care

# %%
df.iloc[4][3]
# Out:
# 'Wholesalers: Health Care'

# %%
df.iloc[1][['Sector','Company']]
# Out:
# Sector          Energy
# Company    Exxon Mobil
# Name: 1, dtype: object

# %%
# loc function
df.loc[3]
# Out:
# Rank                                                4
# Company                            Berkshire Hathaway
# Sector                                     Financials
# Industry     Insurance: Property and Casualty (Stock)
# Location                                    Omaha, NE
# Revenue                                        210821
# Profits                                         24083
# Employees                                      331000
# Name: 3, dtype: object

# %%
df.loc[3]['Company']
# Out:
# 'Berkshire Hathaway'

# %%
df2=pd.read_csv("fortune1000.csv",index_col='Company')
df2
# Out:
#                             Rank                        Sector  \
# Company
# Walmart                        1                     Retailing
# Exxon Mobil                    2                        Energy
# Apple                          3                    Technology
# Berkshire Hathaway             4                    Financials
# McKesson                       5                   Health Care
# ...                          ...                           ...
# New York Community Bancorp   996                    Financials
# Portland General Electric    997                        Energy
# Portland General Electric    997                        Energy
# Wendy’s                      999  Hotels, Resturants & Leisure
# Briggs & Stratton           1000                   Industrials
#
#                                                             Industry  \
# Company
# Walmart                                        General Merchandisers
# ...

# %%
df2.loc['Walmart'][4]
# Out:
# 482130

# %%
df2.loc['Apple'][2:5]
# Out:
# Industry    Computers, Office Equipment
# Location                  Cupertino, CA
# Revenue                          233715
# Name: Apple, dtype: object

# %%
##  find the null values by isnull()

# %%
data2 =df.isnull()
data2
# Out:
#       Rank  Company  Sector  Industry  Location  Revenue  Profits  Employees
# 0    False    False   False     False     False    False    False      False
# 1    False    False   False     False     False    False    False      False
# 2    False    False   False     False     False    False    False      False
# 3    False    False   False     False     False    False    False      False
# 4    False    False   False     False     False    False    False      False
# ..     ...      ...     ...       ...       ...      ...      ...        ...
# 995  False    False   False     False     False    False    False      False
# 996  False    False   False     False     False    False    False      False
# 997  False    False   False     False     False    False    False      False
# 998  False    False   False     False     False    False    False      False
# 999  False    False   False     False     False    False    False      False
#
# [1000 rows x 8 columns]

# %%
data2.isnull().sum()
# Out:
# Rank         0
# Company      0
# Sector       0
# Industry     0
# Location     0
# Revenue      0
# Profits      0
# Employees    0
# dtype: int64

# %%
# series related function

# %%
df["Profits"].sum()
# Out:
# 894093

# %%
df["Profits"].mean()
# Out:
# 894.093

# %%
df["Profits"].max()
# Out:
# 53394

# %%
df["Sector"].mode()
# Out:
# 0    Financials
# dtype: object

# %%
df["Industry"].mode()
# Out:
# 0    Specialty Retailers: Other
# dtype: object

# %%
df["Profits"].var()
# Out:
# 10870628.342693688

# %%
##  concate function

# %%
new_fortune={'Rank':25,'Company':'Dobur','Sector':'Ayurvedic','Location':'pune','Revenue':'62898688',
             'Profits':'8748988667','Employees':'44'}

# %%
new_fortune
# Out:
# {'Rank': 25,
#  'Company': 'Dobur',
#  'Sector': 'Ayurvedic',
#  'Location': 'pune',
#  'Revenue': '62898688',
#  'Profits': '8748988667',
#  'Employees': '44'}

# %%
new_fortune_df=pd.DataFrame(new_fortune,index=[0])
new_fortune_df
# Out:
#    Rank Company     Sector Location   Revenue     Profits Employees
# 0    25   Dobur  Ayurvedic     pune  62898688  8748988667        44

# %%
new_fortune1=pd.concat([new_fortune_df,df],ignore_index=True)
new_fortune1
# Out:
#       Rank                     Company                        Sector  \
# 0       25                       Dobur                     Ayurvedic
# 1        1                     Walmart                     Retailing
# 2        2                 Exxon Mobil                        Energy
# 3        3                       Apple                    Technology
# 4        4          Berkshire Hathaway                    Financials
# ...    ...                         ...                           ...
# 996    996  New York Community Bancorp                    Financials
# 997    997   Portland General Electric                        Energy
# 998    997   Portland General Electric                        Energy
# 999    999                     Wendy’s  Hotels, Resturants & Leisure
# 1000  1000           Briggs & Stratton                   Industrials
#
#              Location   Revenue     Profits Employees  \
# 0                pune  62898688  8748988667        44
# ...

# %%
## Appending function operation

# %%
df.append(new_fortune_df,ignore_index=True)
# Out:
#       Rank                    Company                        Sector  \
# 0        1                    Walmart                     Retailing
# 1        2                Exxon Mobil                        Energy
# 2        3                      Apple                    Technology
# 3        4         Berkshire Hathaway                    Financials
# 4        5                   McKesson                   Health Care
# ...    ...                        ...                           ...
# 996    997  Portland General Electric                        Energy
# 997    997  Portland General Electric                        Energy
# 998    999                    Wendy’s  Hotels, Resturants & Leisure
# 999   1000          Briggs & Stratton                   Industrials
# 1000    25                      Dobur                     Ayurvedic
#
#                                       Industry           Location   Revenue  \
# ...

# %%
## Filtering 
data=df
data
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
data["Industry"]=='Food Service'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Industry, Length: 1000, dtype: bool

# %%
data[data['Profits']>50000]
# Out:
#    Rank Company      Sector                     Industry       Location  \
# 2     3   Apple  Technology  Computers, Office Equipment  Cupertino, CA
#
#    Revenue  Profits  Employees
# 2   233715    53394     110000

# %%
data[data["Industry"] != "Food Service"]
data
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...

# %%
data[data['Profits']>30000]['Industry']
# Out:
# 2    Computers, Office Equipment
# Name: Industry, dtype: object

# %%
data[(data['Profits']>30000) & (df['Revenue']<500000)]
# Out:
#    Rank Company      Sector                     Industry       Location  \
# 2     3   Apple  Technology  Computers, Office Equipment  Cupertino, CA
#
#    Revenue  Profits  Employees
# 2   233715    53394     110000

# %%
data[(data['Profits']>300000) | (data['Revenue']<1000000)]
# Out:
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# 998   999                     Wendy’s  Hotels, Resturants & Leisure
# 999  1000           Briggs & Stratton                   Industrials
#
#                                      Industry           Location  Revenue  \
# 0                       General Merchandisers    Bentonville, AR   482130
# ...
